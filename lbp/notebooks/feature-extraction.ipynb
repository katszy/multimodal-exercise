# %%
from lbp.notebooks.scripts.emg_features import *
from scipy.fftpack import fft
from scipy.stats import entropy, skew, kurtosis
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
from scipy.integrate import simpson

# %%
df = pd.read_pickle("data/df_for_feature_extraction_with_emg.pkl")

# %%
df.shape
# Out:
# (7614602, 150)

# %%
df = df.drop(columns=['Frame', 'Sample', 'empty_1','empty_2'])

# %% [markdown]
# # feature extraction

# %%
def extract_features(df, sampling_rate=1000):
    """
    Extracts features for acc, ang_acc, vel, ang_vel, joint_angle, and EMG data, along with RM and OI values for each repetition.

    Parameters:
    df (pd.DataFrame): Time-series data containing acc, ang_acc, vel, ang_vel, joint_angle, EMG, RM, and OI.
    sampling_rate (int): Sampling rate of the EMG data (default is 1000 Hz).

    Returns:
    pd.DataFrame: A DataFrame containing extracted features with associated RM and OI values.
    """
    feature_list = []
    skipped_reps = []

    # Get the unique participants, sessions, and exercises
    participants = df['Participant'].unique()
    sessions = df['session_id'].unique()
    exercises = df['Marker'].unique()

    # Define EMG columns
    emg_columns_envelope = [col for col in df.columns if 'envelope' in col]
    emg_columns_bandpassed = [col for col in df.columns if 'bandpassed' in col]

    # Loop through participants, sessions, and exercises
    for participant in participants:
        for session in sessions:
            for exercise in exercises:
                exercise_data = df[(df['Participant'] == participant) &
                                   (df['session_id'] == session) &
                                   (df['Marker'] == exercise)]

                reps = exercise_data['Reps'].unique()  # Get unique reps within this exercise

                # Loop through each repetition within the exercise
                for rep in reps:
                    print("Processing Rep:", rep)
                    rep_data = exercise_data[exercise_data['Reps'] == rep]

                    # Ensure there are enough data points for feature extraction
                    if rep_data.empty or len(rep_data) < 2:
                        skipped_reps.append((participant, session, exercise, rep, "Empty or insufficient data"))
                        continue

                    # Extract RM and OI values for the current rep
                    rm_value = rep_data['RM'].iloc[0]
                    oi_value = rep_data['OI'].iloc[0]

                    feature_dict = {
                        'Participant': participant,
                        'session_id': session,
                        'Exercise': exercise,
                        'Rep': rep,
                        'Roland-Morris': rm_value,
                        'Oswestry Index': oi_value
                    }

                    # Add EMG envelope features
                    for col in emg_columns_envelope:
                        if col not in rep_data.columns or rep_data[col].isnull().all():
                            continue
                        try:
                            envelope_col = rep_data[col].dropna().values
                            feature_dict.update({
                                f'{col}_IEMG': CalcIEMG(rep_data, col, sampling_rate),
                                f'{col}_MAV': CalcMAV(rep_data, col),
                                f'{col}_MMAV': CalcMMAV(rep_data, col),
                                f'{col}_SSI': CalcSSI(rep_data, col, sampling_rate),
                                f'{col}_VAR': CalcVAR(rep_data, col),
                                f'{col}_VOrder': CalcVOrder(rep_data, col),
                                f'{col}_RMS': CalcRMS(rep_data, col),
                                f'{col}_WL': CalcWL(rep_data, col),
                                f'{col}_LOG': CalcLOG(rep_data, col),
                                f'{col}_MFL': CalcMFL(rep_data, col),
                                f'{col}_AP': CalcAP(rep_data, col),
                                f'{col}_Min': np.min(envelope_col),
                                f'{col}_Max': np.max(envelope_col),
                                f'{col}_Mean': np.mean(envelope_col),
                                f'{col}_SD': np.std(envelope_col),
                                f'{col}_Skew': skew(envelope_col),
                                f'{col}_Kurtosis': kurtosis(envelope_col),
                            })
                        except Exception as e:
                            skipped_reps.append((participant, session, exercise, rep, f"Error processing EMG envelope '{col}': {e}"))

                    # Add EMG bandpassed spectral features
                    for col in emg_columns_bandpassed:
                        if col not in rep_data.columns or rep_data[col].isnull().all():
                            continue
                        try:
                            data_col = rep_data[col].dropna().values
                            psd = EMG2PSD(data_col, sr=sampling_rate)
                            feature_dict.update({
                                f'{col}_Max_Freq': psd.iloc[psd['Power'].idxmax()]['Frequency'],
                                f'{col}_Twitch_Ratio': CalcTwitchRatio(psd),
                                f'{col}_Twitch_Index': CalcTwitchIndex(psd),
                                f'{col}_Fast_Twitch_Slope': CalcTwitchSlope(psd)[0],
                                f'{col}_Slow_Twitch_Slope': CalcTwitchSlope(psd)[1],
                                f'{col}_Spectral_Centroid': CalcSC(psd),
                                f'{col}_Spectral_Flatness': CalcSF(psd),
                                f'{col}_Spectral_Spread': CalcSS(psd),
                                f'{col}_Spectral_Decrease': CalcSDec(psd),
                                f'{col}_Spectral_Entropy': CalcSEntropy(psd),
                                f'{col}_Spectral_Rolloff': CalcSRoll(psd),
                                f'{col}_Spectral_Bandwidth': CalcSBW(psd, 2),
                            })
                        except Exception as e:
                            skipped_reps.append((participant, session, exercise, rep, f"Error processing EMG bandpassed '{col}': {e}"))

                    # Add motion features
                    motion_columns = [col for col in rep_data.columns if any(sub in col for sub in ['acc', 'ang_acc', 'vel', 'ang_vel'])]
                    for col in motion_columns:
                        series = rep_data[col].dropna().values
                        if len(series) < 2:
                            continue

                        abs_series = np.abs(series)
                        fft_coefficients = fft(series)
                        abs_fft_coefficients = np.abs(fft_coefficients)
                        spectral_entropy = entropy(abs_fft_coefficients)

                        # Number of Mean Crossing Points (NMCP-A)
                        mean_value = np.mean(series)
                        nmcp_a = np.sum((series[:-1] - mean_value) * (series[1:] - mean_value) < 0)

                        # Number of Peaks in Acceleration (NP-A)
                        peaks, _ = find_peaks(series)
                        np_a = len(peaks)

                        # Spectral Arc Length (SPARC)
                        # Normalize the signal
                        normalized_fft = abs_fft_coefficients / np.sum(abs_fft_coefficients)
                        omega = np.linspace(0, np.pi, len(normalized_fft))
                        spectral_arc_length = -simpson(np.sqrt(np.diff(normalized_fft)**2 + np.diff(omega)**2))

                        # Log Dimensionless Jerk in Acceleration (LDLJ-A)
                        time_step = 1 / 1000 
                        jerk = np.diff(series, n=2) / (time_step ** 2)  # Second derivative (jerk)
                        ljerk = np.sum(np.square(jerk)) / ((len(series) - 2) ** 3)
                        ldlj_a = np.log(ljerk + 1e-10)  # Adding a small constant to avoid log(0)

                        # Add motion feature data to feature_dict
                        feature_dict.update({
                            f'{col}_mean': np.mean(series),
                            f'{col}_std': np.std(series, ddof=1),
                            f'{col}_range': np.max(series) - np.min(series),
                            f'{col}_mean_abs': np.mean(abs_series),
                            f'{col}_variance': np.var(series, ddof=1),
                            f'{col}_rms': np.sqrt(np.mean(np.square(series))),
                            f'{col}_skewness': skew(series),
                            f'{col}_kurtosis': kurtosis(series),
                            f'{col}_energy': np.sum(np.square(series)),
                            f'{col}_spectral_entropy': spectral_entropy,
                            f'{col}_abs_max_fft_coeff': np.max(abs_fft_coefficients),
                            f'{col}_abs_min_fft_coeff': np.min(abs_fft_coefficients),
                            f'{col}_sma': np.mean(np.abs(series)),
                            f'{col}_nmcp_a': nmcp_a,
                            f'{col}_np_a': np_a,
                            f'{col}_sparc': spectral_arc_length,
                            f'{col}_ldlj_a': ldlj_a,
                        })

                    # Extract joint angle features
                    joint_angle_columns = [col for col in rep_data.columns if 'joint_angle' in col]
                    for col in joint_angle_columns:
                        series = rep_data[col].dropna().values
                        if len(series) < 2:
                            continue

                        # Add joint angle feature data
                        feature_dict.update({
                            f'{col}_ROM': np.abs(np.max(series) - np.min(series)),
                            f'{col}_mean': np.mean(series),
                            f'{col}_skewness': skew(series),
                        })

                    feature_list.append(feature_dict)

    feature_df = pd.DataFrame(feature_list)
    return feature_df
d = extract_features(df)
print(d.shape)
# Out:
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 10.0
# Processing Rep: 11.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 18.0
# Processing Rep: 16.0
# Processing Rep: 18.0
# Processing Rep: 25.0
# Processing Rep: 32.0
# Processing Rep: 37.0
# Processing Rep: 12.0
# Processing Rep: 8.0
# Processing Rep: 20.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 26.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 29.0
# Processing Rep: 30.0
# Processing Rep: 31.0
# Processing Rep: 33.0
# Processing Rep: 34.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 37.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 45.0
# Processing Rep: 47.0
# Processing Rep: 40.0
# Processing Rep: 52.0
# Processing Rep: 54.0
# Processing Rep: 58.0
# Processing Rep: 60.0
# Processing Rep: 70.0
# Processing Rep: 72.0
# Processing Rep: 42.0
# Processing Rep: 62.0
# Processing Rep: 74.0
# Processing Rep: 46.0
# Processing Rep: 44.0
# Processing Rep: 64.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 52.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 55.0
# Processing Rep: 56.0
# Processing Rep: 57.0
# Processing Rep: 58.0
# Processing Rep: 59.0
# Processing Rep: 77.0
# Processing Rep: 89.0
# Processing Rep: 91.0
# Processing Rep: 97.0
# Processing Rep: 99.0
# Processing Rep: 107.0
# Processing Rep: 79.0
# Processing Rep: 101.0
# Processing Rep: 109.0
# Processing Rep: 83.0
# Processing Rep: 81.0
# Processing Rep: 62.0
# Processing Rep: 63.0
# Processing Rep: 64.0
# Processing Rep: 65.0
# Processing Rep: 66.0
# Processing Rep: 67.0
# Processing Rep: 112.0
# Processing Rep: 126.0
# Processing Rep: 114.0
# Processing Rep: 128.0
# Processing Rep: 118.0
# Processing Rep: 134.0
# Processing Rep: 116.0
# Processing Rep: 130.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 11.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 19.0
# Processing Rep: 20.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 3.0
# Processing Rep: 5.0
# Processing Rep: 19.0
# Processing Rep: 28.0
# Processing Rep: 30.0
# Processing Rep: 34.0
# Processing Rep: 45.0
# Processing Rep: 47.0
# Processing Rep: 55.0
# Processing Rep: 7.0
# Processing Rep: 15.0
# Processing Rep: 9.0
# Processing Rep: 11.0
# Processing Rep: 13.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 29.0
# Processing Rep: 30.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 60.0
# Processing Rep: 68.0
# Processing Rep: 72.0
# Processing Rep: 74.0
# Processing Rep: 83.0
# Processing Rep: 85.0
# Processing Rep: 91.0
# Processing Rep: 93.0
# Processing Rep: 97.0
# Processing Rep: 103.0
# Processing Rep: 105.0
# Processing Rep: 109.0
# Processing Rep: 58.0
# Processing Rep: 76.0
# Processing Rep: 78.0
# Processing Rep: 87.0
# Processing Rep: 89.0
# Processing Rep: 99.0
# Processing Rep: 111.0
# Processing Rep: 64.0
# Processing Rep: 62.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 114.0
# Processing Rep: 126.0
# Processing Rep: 128.0
# Processing Rep: 132.0
# Processing Rep: 134.0
# Processing Rep: 138.0
# Processing Rep: 116.0
# Processing Rep: 136.0
# Processing Rep: 142.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 46.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 55.0
# Processing Rep: 56.0
# Processing Rep: 57.0
# Processing Rep: 58.0
# Processing Rep: 145.0
# Processing Rep: 157.0
# Processing Rep: 159.0
# Processing Rep: 167.0
# Processing Rep: 169.0
# Processing Rep: 175.0
# Processing Rep: 177.0
# Processing Rep: 183.0
# Processing Rep: 191.0
# Processing Rep: 147.0
# Processing Rep: 161.0
# Processing Rep: 163.0
# Processing Rep: 171.0
# Processing Rep: 179.0
# Processing Rep: 185.0
# Processing Rep: 187.0
# Processing Rep: 151.0
# Processing Rep: 149.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 10.0
# Processing Rep: 11.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 4.0
# Processing Rep: 12.0
# Processing Rep: 23.0
# Processing Rep: 25.0
# Processing Rep: 32.0
# Processing Rep: 40.0
# Processing Rep: 17.0
# Processing Rep: 27.0
# Processing Rep: 34.0
# Processing Rep: 42.0
# Processing Rep: 8.0
# Processing Rep: 18.0
# Processing Rep: 19.0
# Processing Rep: 20.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 29.0
# Processing Rep: 30.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 34.0
# Processing Rep: 45.0
# Processing Rep: 47.0
# Processing Rep: 59.0
# Processing Rep: 70.0
# Processing Rep: 49.0
# Processing Rep: 53.0
# Processing Rep: 51.0
# Processing Rep: 61.0
# Processing Rep: 36.0
# Processing Rep: 37.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 73.0
# Processing Rep: 85.0
# Processing Rep: 91.0
# Processing Rep: 75.0
# Processing Rep: 87.0
# Processing Rep: 93.0
# Processing Rep: 79.0
# Processing Rep: 77.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 96.0
# Processing Rep: 108.0
# Processing Rep: 98.0
# Processing Rep: 110.0
# Processing Rep: 102.0
# Processing Rep: 116.0
# Processing Rep: 100.0
# Processing Rep: 112.0
# Processing Rep: 4.0
# Processing Rep: 12.0
# Processing Rep: 8.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 29.0
# Processing Rep: 51.0
# Processing Rep: 77.0
# Processing Rep: 53.0
# Processing Rep: 55.0
# Processing Rep: 59.0
# Processing Rep: 57.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 80.0
# Processing Rep: 97.0
# Processing Rep: 99.0
# Processing Rep: 82.0
# Processing Rep: 90.0
# Processing Rep: 86.0
# Processing Rep: 101.0
# Processing Rep: 36.0
# Processing Rep: 37.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 46.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 52.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 55.0
# Processing Rep: 56.0
# Processing Rep: 110.0
# Processing Rep: 112.0
# Processing Rep: 131.0
# Processing Rep: 147.0
# Processing Rep: 149.0
# Processing Rep: 159.0
# Processing Rep: 133.0
# Processing Rep: 135.0
# Processing Rep: 151.0
# Processing Rep: 153.0
# Processing Rep: 161.0
# Processing Rep: 118.0
# Processing Rep: 116.0
# Processing Rep: 137.0
# Processing Rep: 157.0
# Processing Rep: 58.0
# Processing Rep: 59.0
# Processing Rep: 60.0
# Processing Rep: 61.0
# Processing Rep: 62.0
# Processing Rep: 64.0
# Processing Rep: 65.0
# Processing Rep: 66.0
# Processing Rep: 67.0
# Processing Rep: 68.0
# Processing Rep: 69.0
# Processing Rep: 70.0
# Processing Rep: 71.0
# Processing Rep: 72.0
# Processing Rep: 164.0
# Processing Rep: 185.0
# Processing Rep: 166.0
# Processing Rep: 199.0
# Processing Rep: 170.0
# Processing Rep: 205.0
# Processing Rep: 168.0
# Processing Rep: 189.0
# Processing Rep: 201.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 10.0
# Processing Rep: 11.0
# Processing Rep: 3.0
# Processing Rep: 15.0
# Processing Rep: 17.0
# Processing Rep: 19.0
# Processing Rep: 27.0
# Processing Rep: 29.0
# Processing Rep: 34.0
# Processing Rep: 36.0
# Processing Rep: 23.0
# Processing Rep: 40.0
# Processing Rep: 9.0
# Processing Rep: 7.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 18.0
# Processing Rep: 19.0
# Processing Rep: 20.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 26.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 43.0
# Processing Rep: 55.0
# Processing Rep: 63.0
# Processing Rep: 45.0
# Processing Rep: 57.0
# Processing Rep: 59.0
# Processing Rep: 65.0
# Processing Rep: 67.0
# Processing Rep: 49.0
# Processing Rep: 47.0
# Processing Rep: 30.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 34.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 46.0
# Processing Rep: 70.0
# Processing Rep: 84.0
# Processing Rep: 90.0
# Processing Rep: 92.0
# Processing Rep: 100.0
# Processing Rep: 102.0
# Processing Rep: 106.0
# Processing Rep: 72.0
# Processing Rep: 86.0
# Processing Rep: 94.0
# Processing Rep: 108.0
# Processing Rep: 78.0
# Processing Rep: 74.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 52.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 111.0
# Processing Rep: 123.0
# Processing Rep: 125.0
# Processing Rep: 131.0
# Processing Rep: 133.0
# Processing Rep: 139.0
# Processing Rep: 141.0
# Processing Rep: 113.0
# Processing Rep: 127.0
# Processing Rep: 135.0
# Processing Rep: 143.0
# Processing Rep: 117.0
# Processing Rep: 115.0
# Processing Rep: 16.0
# Processing Rep: 12.0
# Processing Rep: 8.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 10.0
# Processing Rep: 11.0
# Processing Rep: 25.0
# Processing Rep: 28.0
# Processing Rep: 34.0
# Processing Rep: 42.0
# Processing Rep: 44.0
# Processing Rep: 46.0
# Processing Rep: 30.0
# Processing Rep: 38.0
# Processing Rep: 50.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 18.0
# Processing Rep: 19.0
# Processing Rep: 20.0
# Processing Rep: 63.0
# Processing Rep: 67.0
# Processing Rep: 75.0
# Processing Rep: 65.0
# Processing Rep: 77.0
# Processing Rep: 57.0
# Processing Rep: 55.0
# Processing Rep: 79.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 26.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 29.0
# Processing Rep: 30.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 34.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 37.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 84.0
# Processing Rep: 106.0
# Processing Rep: 108.0
# Processing Rep: 116.0
# Processing Rep: 124.0
# Processing Rep: 86.0
# Processing Rep: 118.0
# Processing Rep: 126.0
# Processing Rep: 90.0
# Processing Rep: 88.0
# Processing Rep: 110.0
# Processing Rep: 120.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 52.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 56.0
# Processing Rep: 57.0
# Processing Rep: 58.0
# Processing Rep: 59.0
# Processing Rep: 60.0
# Processing Rep: 61.0
# Processing Rep: 62.0
# Processing Rep: 63.0
# Processing Rep: 64.0
# Processing Rep: 65.0
# Processing Rep: 129.0
# Processing Rep: 143.0
# Processing Rep: 131.0
# Processing Rep: 145.0
# Processing Rep: 135.0
# Processing Rep: 149.0
# Processing Rep: 133.0
# Processing Rep: 147.0
# Processing Rep: 4.0
# Processing Rep: 8.0
# Processing Rep: 6.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 10.0
# Processing Rep: 16.0
# Processing Rep: 27.0
# Processing Rep: 33.0
# Processing Rep: 18.0
# Processing Rep: 29.0
# Processing Rep: 35.0
# Processing Rep: 21.0
# Processing Rep: 20.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 18.0
# Processing Rep: 19.0
# Processing Rep: 20.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 38.0
# Processing Rep: 50.0
# Processing Rep: 54.0
# Processing Rep: 56.0
# Processing Rep: 40.0
# Processing Rep: 46.0
# Processing Rep: 42.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 9.0
# Processing Rep: 10.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 18.0
# Processing Rep: 27.0
# Processing Rep: 31.0
# Processing Rep: 35.0
# Processing Rep: 41.0
# Processing Rep: 9.0
# Processing Rep: 19.0
# Processing Rep: 33.0
# Processing Rep: 37.0
# Processing Rep: 13.0
# Processing Rep: 11.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 26.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 30.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 46.0
# Processing Rep: 57.0
# Processing Rep: 61.0
# Processing Rep: 48.0
# Processing Rep: 52.0
# Processing Rep: 50.0
# Processing Rep: 34.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 37.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 78.0
# Processing Rep: 87.0
# Processing Rep: 80.0
# Processing Rep: 89.0
# Processing Rep: 82.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 46.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 102.0
# Processing Rep: 116.0
# Processing Rep: 118.0
# Processing Rep: 122.0
# Processing Rep: 124.0
# Processing Rep: 128.0
# Processing Rep: 130.0
# Processing Rep: 104.0
# Processing Rep: 136.0
# Processing Rep: 108.0
# Processing Rep: 106.0
# Processing Rep: 1.0
# Processing Rep: 2.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 10.0
# Processing Rep: 11.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 19.0
# Processing Rep: 20.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 26.0
# Processing Rep: 27.0
# Processing Rep: 6.0
# Processing Rep: 15.0
# Processing Rep: 26.0
# Processing Rep: 28.0
# Processing Rep: 39.0
# Processing Rep: 41.0
# Processing Rep: 8.0
# Processing Rep: 19.0
# Processing Rep: 34.0
# Processing Rep: 10.0
# Processing Rep: 29.0
# Processing Rep: 30.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 34.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 38.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 44.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 52.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 55.0
# Processing Rep: 56.0
# Processing Rep: 44.0
# Processing Rep: 52.0
# Processing Rep: 57.0
# Processing Rep: 61.0
# Processing Rep: 63.0
# Processing Rep: 71.0
# Processing Rep: 46.0
# Processing Rep: 69.0
# Processing Rep: 48.0
# Processing Rep: 58.0
# Processing Rep: 59.0
# Processing Rep: 60.0
# Processing Rep: 61.0
# Processing Rep: 62.0
# Processing Rep: 63.0
# Processing Rep: 64.0
# Processing Rep: 65.0
# Processing Rep: 74.0
# Processing Rep: 86.0
# Processing Rep: 92.0
# Processing Rep: 76.0
# Processing Rep: 88.0
# Processing Rep: 94.0
# Processing Rep: 80.0
# Processing Rep: 72.0
# Processing Rep: 73.0
# Processing Rep: 74.0
# Processing Rep: 75.0
# Processing Rep: 76.0
# Processing Rep: 78.0
# Processing Rep: 80.0
# Processing Rep: 82.0
# Processing Rep: 83.0
# Processing Rep: 84.0
# Processing Rep: 85.0
# Processing Rep: 86.0
# Processing Rep: 87.0
# Processing Rep: 88.0
# Processing Rep: 89.0
# Processing Rep: 90.0
# Processing Rep: 91.0
# Processing Rep: 92.0
# Processing Rep: 100.0
# Processing Rep: 112.0
# Processing Rep: 119.0
# Processing Rep: 127.0
# Processing Rep: 137.0
# Processing Rep: 139.0
# Processing Rep: 102.0
# Processing Rep: 114.0
# Processing Rep: 121.0
# Processing Rep: 129.0
# Processing Rep: 141.0
# Processing Rep: 108.0
# Processing Rep: 104.0
# Processing Rep: 123.0
# Processing Rep: 131.0
# Processing Rep: 143.0
# Processing Rep: 94.0
# Processing Rep: 95.0
# Processing Rep: 96.0
# Processing Rep: 97.0
# Processing Rep: 98.0
# Processing Rep: 99.0
# Processing Rep: 100.0
# Processing Rep: 101.0
# Processing Rep: 102.0
# Processing Rep: 103.0
# Processing Rep: 146.0
# Processing Rep: 148.0
# Processing Rep: 162.0
# Processing Rep: 154.0
# Processing Rep: 150.0
# Processing Rep: 3.0
# Processing Rep: 4.0
# Processing Rep: 5.0
# Processing Rep: 6.0
# Processing Rep: 7.0
# Processing Rep: 8.0
# Processing Rep: 23.0
# Processing Rep: 27.0
# Processing Rep: 39.0
# Processing Rep: 41.0
# Processing Rep: 45.0
# Processing Rep: 47.0
# Processing Rep: 72.0
# Processing Rep: 6.0
# Processing Rep: 19.0
# Processing Rep: 55.0
# Processing Rep: 59.0
# Processing Rep: 63.0
# Processing Rep: 74.0
# Processing Rep: 8.0
# Processing Rep: 43.0
# Processing Rep: 77.0
# Processing Rep: 79.0
# Processing Rep: 89.0
# Processing Rep: 113.0
# Processing Rep: 115.0
# Processing Rep: 124.0
# Processing Rep: 81.0
# Processing Rep: 93.0
# Processing Rep: 104.0
# Processing Rep: 117.0
# Processing Rep: 126.0
# Processing Rep: 85.0
# Processing Rep: 95.0
# Processing Rep: 11.0
# Processing Rep: 12.0
# Processing Rep: 13.0
# Processing Rep: 14.0
# Processing Rep: 15.0
# Processing Rep: 16.0
# Processing Rep: 17.0
# Processing Rep: 18.0
# Processing Rep: 19.0
# Processing Rep: 21.0
# Processing Rep: 22.0
# Processing Rep: 23.0
# Processing Rep: 24.0
# Processing Rep: 25.0
# Processing Rep: 26.0
# Processing Rep: 27.0
# Processing Rep: 28.0
# Processing Rep: 29.0
# Processing Rep: 31.0
# Processing Rep: 32.0
# Processing Rep: 33.0
# Processing Rep: 34.0
# Processing Rep: 35.0
# Processing Rep: 36.0
# Processing Rep: 37.0
# Processing Rep: 138.0
# Processing Rep: 140.0
# Processing Rep: 153.0
# Processing Rep: 161.0
# Processing Rep: 168.0
# Processing Rep: 182.0
# Processing Rep: 184.0
# Processing Rep: 142.0
# Processing Rep: 155.0
# Processing Rep: 148.0
# Processing Rep: 144.0
# Processing Rep: 172.0
# Processing Rep: 39.0
# Processing Rep: 40.0
# Processing Rep: 41.0
# Processing Rep: 42.0
# Processing Rep: 43.0
# Processing Rep: 44.0
# Processing Rep: 45.0
# Processing Rep: 46.0
# Processing Rep: 47.0
# Processing Rep: 48.0
# Processing Rep: 49.0
# Processing Rep: 50.0
# Processing Rep: 51.0
# Processing Rep: 53.0
# Processing Rep: 54.0
# Processing Rep: 55.0
# Processing Rep: 56.0
# Processing Rep: 57.0
# Processing Rep: 58.0
# Processing Rep: 60.0
# Processing Rep: 62.0
# Processing Rep: 63.0
# Processing Rep: 64.0
# Processing Rep: 65.0
# Processing Rep: 66.0
# Processing Rep: 67.0
# Processing Rep: 68.0
# Processing Rep: 69.0
# Processing Rep: 187.0
# Processing Rep: 201.0
# Processing Rep: 207.0
# Processing Rep: 189.0
# Processing Rep: 203.0
# Processing Rep: 209.0
# Processing Rep: 193.0
# Processing Rep: 191.0
# Processing Rep: 211.0
# Processing Rep: 213.0
# Processing Rep: 71.0
# Processing Rep: 72.0
# Processing Rep: 73.0
# Processing Rep: 74.0
# Processing Rep: 75.0
# Processing Rep: 76.0
# Processing Rep: 77.0
# Processing Rep: 78.0
# Processing Rep: 80.0
# Processing Rep: 81.0
# Processing Rep: 82.0
# Processing Rep: 83.0
# Processing Rep: 84.0
# Processing Rep: 85.0
# Processing Rep: 86.0
# Processing Rep: 88.0
# Processing Rep: 89.0
# Processing Rep: 90.0
# Processing Rep: 91.0
# Processing Rep: 92.0
# Processing Rep: 94.0
# Processing Rep: 95.0
# Processing Rep: 216.0
# Processing Rep: 234.0
# Processing Rep: 236.0
# Processing Rep: 238.0
# Processing Rep: 250.0
# Processing Rep: 252.0
# Processing Rep: 260.0
# Processing Rep: 262.0
# Processing Rep: 264.0
# Processing Rep: 274.0
# Processing Rep: 276.0
# Processing Rep: 288.0
# Processing Rep: 218.0
# Processing Rep: 240.0
# Processing Rep: 242.0
# Processing Rep: 254.0
# Processing Rep: 266.0
# Processing Rep: 268.0
# Processing Rep: 278.0
# Processing Rep: 280.0
# Processing Rep: 290.0
# Processing Rep: 222.0
# Processing Rep: 286.0
# Processing Rep: 220.0
# Processing Rep: 244.0
# Processing Rep: 256.0
# Processing Rep: 282.0
# (970, 2041)

# %% [markdown]
# # remove correlated ones

# %%
def remove_highly_correlated_numerical_keep_one(df, threshold=0.90):
    """
    Removes highly correlated numerical columns from the DataFrame while retaining one feature from each group of correlated features.
    """
    
    # Separate 'Participant' column to keep it intact
    non_numerical_cols = df.select_dtypes(exclude=['number']).columns.tolist()

    numerical_df = df.drop(columns=non_numerical_cols).select_dtypes(include=['number'])
    corr_matrix = numerical_df.corr().abs()

    to_drop = set()
    retained = set()

    for col in corr_matrix.columns:
        if col in to_drop:
            continue
        correlated_features = corr_matrix.columns[corr_matrix[col] > threshold].tolist()
        correlated_features = [f for f in correlated_features if f != col and f not in retained]
        to_drop.update(correlated_features)
        retained.add(col)

    # Exclude target columns 
    excluded_cols = ['Oswestry Index', 'Roland-Morris', 'session_id', 'Reps']
    to_drop = [col for col in to_drop if col not in excluded_cols]
    
    return df.drop(columns=to_drop), list(retained)

filtered_features_df_numerical, retained_features = remove_highly_correlated_numerical_keep_one(d)
print(d.shape)
print(filtered_features_df_numerical.shape)
# Out:
# (970, 2041)
# (970, 748)

# %%
filtered_features_df_numerical.to_pickle("df_for_predictions.pkl")
